# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tokyo_21 = pd.read_csv("Tokyo 2021 dataset.csv")

# %%
tokyo_21
# Out:
#     Rank                    Team/NOC  Gold Medal  Silver Medal  Bronze Medal  \
# 0      1    United States of America          39            41            33
# 1      2  People's Republic of China          38            32            18
# 2      3                       Japan          27            14            17
# 3      4               Great Britain          22            21            22
# 4      5                         ROC          20            28            23
# ..   ...                         ...         ...           ...           ...
# 88    86                       Ghana           0             0             1
# 89    86                     Grenada           0             0             1
# 90    86                      Kuwait           0             0             1
# 91    86         Republic of Moldova           0             0             1
# 92    86        Syrian Arab Republic           0             0             1
#
#     Total  Rank by Total NOCCode
# ...

# %%
tokyo_21.info
# Out:
# <bound method DataFrame.info of     Rank                    Team/NOC  Gold Medal  Silver Medal  Bronze Medal  \
# 0      1    United States of America          39            41            33
# 1      2  People's Republic of China          38            32            18
# 2      3                       Japan          27            14            17
# 3      4               Great Britain          22            21            22
# 4      5                         ROC          20            28            23
# ..   ...                         ...         ...           ...           ...
# 88    86                       Ghana           0             0             1
# 89    86                     Grenada           0             0             1
# 90    86                      Kuwait           0             0             1
# 91    86         Republic of Moldova           0             0             1
# 92    86        Syrian Arab Republic           0             0             1
#
# ...

# %%
# First 5 Countries in the data
tokyo_21.head()
# Out:
#    Rank                    Team/NOC  Gold Medal  Silver Medal  Bronze Medal  \
# 0     1    United States of America          39            41            33
# 1     2  People's Republic of China          38            32            18
# 2     3                       Japan          27            14            17
# 3     4               Great Britain          22            21            22
# 4     5                         ROC          20            28            23
#
#    Total  Rank by Total NOCCode
# 0    113              1     USA
# 1     88              2     CHN
# 2     58              5     JPN
# 3     65              4     GBR
# 4     71              3     ROC

# %%
# last 5 Countries in the data
tokyo_21.tail()
# Out:
#     Rank              Team/NOC  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 88    86                 Ghana           0             0             1      1
# 89    86               Grenada           0             0             1      1
# 90    86                Kuwait           0             0             1      1
# 91    86   Republic of Moldova           0             0             1      1
# 92    86  Syrian Arab Republic           0             0             1      1
#
#     Rank by Total NOCCode
# 88             77     GHA
# 89             77     GRN
# 90             77     KUW
# 91             77     MDA
# 92             77     SYR

# %%
# A summary of the data
tokyo_21.describe()
# Out:
#             Rank  Gold Medal  Silver Medal  Bronze Medal       Total  \
# count  93.000000   93.000000     93.000000     93.000000   93.000000
# mean   46.333333    3.655914      3.634409      4.322581   11.612903
# std    26.219116    7.022471      6.626339      6.210372   19.091332
# min     1.000000    0.000000      0.000000      0.000000    1.000000
# 25%    24.000000    0.000000      0.000000      1.000000    2.000000
# 50%    46.000000    1.000000      1.000000      2.000000    4.000000
# 75%    70.000000    3.000000      4.000000      5.000000   11.000000
# max    86.000000   39.000000     41.000000     33.000000  113.000000
#
#        Rank by Total
# count      93.000000
# mean       43.494624
# std        24.171769
# min         1.000000
# 25%        23.000000
# 50%        47.000000
# 75%        66.000000
# max        77.000000

# %% [markdown]
# The average number of Gold and Silver Medals gained by most Teams in the olympic are 3 and  for Bronze Medals are 4.
# The maximum number of medals gained in the olympic all came from one Team, Team United States

# %%
tokyo_21.sort_values(by=['Rank by Total'],ascending=True)
# Out:
#     Rank                    Team/NOC  Gold Medal  Silver Medal  Bronze Medal  \
# 0      1    United States of America          39            41            33
# 1      2  People's Republic of China          38            32            18
# 4      5                         ROC          20            28            23
# 3      4               Great Britain          22            21            22
# 2      3                       Japan          27            14            17
# ..   ...                         ...         ...           ...           ...
# 76    77                     Bahrain           0             1             0
# 62    63                     Bermuda           1             0             0
# 63    63                     Morocco           1             0             0
# 81    77                Turkmenistan           0             1             0
# 92    86        Syrian Arab Republic           0             0             1
#
#     Total  Rank by Total NOCCode
# ...

# %%
tokyo_21.sort_values(by=['Total'],ascending=False).head()
# Out:
#    Rank                    Team/NOC  Gold Medal  Silver Medal  Bronze Medal  \
# 0     1    United States of America          39            41            33
# 1     2  People's Republic of China          38            32            18
# 4     5                         ROC          20            28            23
# 3     4               Great Britain          22            21            22
# 2     3                       Japan          27            14            17
#
#    Total  Rank by Total NOCCode
# 0    113              1     USA
# 1     88              2     CHN
# 4     71              3     ROC
# 3     65              4     GBR
# 2     58              5     JPN

# %%
selected_teams =[18,36,53,57]

# %%
tokyo_21['Gold Medal'].loc[selected_teams]
# Out:
# 18    4
# 36    2
# 53    1
# 57    1
# Name: Gold Medal, dtype: int64

# %%
# A sample of African Teams in the Olympics
tokyo_21.loc[selected_teams]
# Out:
#     Rank Team/NOC  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 18    19    Kenya           4             4             2     10
# 36    36   Uganda           2             1             1      4
# 53    54    Egypt           1             1             4      6
# 57    58  Tunisia           1             1             0      2
#
#     Rank by Total NOCCode
# 18             25     KEN
# 36             47     UGA
# 53             39     EGY
# 57             66     TUN

# %% [markdown]
# From Africa the teams that participated in the olympics, Kenya had the highest number of medals acquired with a total of 10 Medals.

# %%
# A bar representation of all teams that had Gold Medals
tokyo_21['Gold Medal'].value_counts().plot(kind='bar', title='Gold Medal')
# Out:
# <AxesSubplot:title={'center':'Gold Medal'}>

# %%
# Histograms for all the Numerical data
tokyo_21.hist(edgecolor='black',bins=25, figsize=(14,5),layout =(2,4));
